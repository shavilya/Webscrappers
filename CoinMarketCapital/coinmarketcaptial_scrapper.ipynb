# %%
from requests import Request,Session 
from requests.exceptions import ConnectionError , Timeout , TooManyRedirects 

import os 
from time import time 
from time import sleep

import json 
import pandas as pd 

pd.set_option('display.max_columns' , None)
pd.set_option('display.max_rows' , None)

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now' ,utc = True)

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9764
# 1   1027     Ethereum    ETH              ethereum              6125
# 2    825       Tether   USDT                tether             40506
# 3   1839          BNB    BNB                   bnb              1121
# 4   3408     USD Coin   USDC              usd-coin              6437
# 5     52          XRP    XRP                   xrp               826
# 6   4687  Binance USD   BUSD           binance-usd              5231
# 7   2010      Cardano    ADA               cardano               577
# 8   5426       Solana    SOL                solana               389
# 9     74     Dogecoin   DOGE              dogecoin               571
# 10  3890      Polygon  MATIC               polygon               495
# 11  6636     Polkadot    DOT          polkadot-new               418
# 12  4943          Dai    DAI  multi-collateral-dai              1409
# ...

# %%
def api_runner() : 
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'2000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

df2 = pd.json_normalize(data['data'])
df2['timestamp'] = pd.to_datetime('now' ,utc = True)

df = df.append(df2) 

if not os.path.isfile(r'A:\Webscrappers\CoinMarketCapital\API.csv') : 
  df.to_csv('A:\Webscrappers\CoinMarketCapital\API.csv' , header = 'column_names')

else : 
  df.to_csv('A:\Webscrappers\CoinMarketCapital\API.csv' , header = False , mode = 'a' )
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19936\924871971.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %%
 


for i in range(333) :  # Total credits on coinmarketcap API is 333. 
    api_runner() 
    print("API Running completed .")
    sleep(60) # Sleep for 1 minute. 

exit()
# Out:
# API Running completed .
# API Running completed .
# API Running completed .

# %%
df3 = pd.read_csv('A:\Webscrappers\CoinMarketCapital\API.csv')

df3.head()
# Out:
#    Unnamed: 0    id      name symbol      slug  num_market_pairs  \
# 0           0     1   Bitcoin    BTC   bitcoin              9764
# 1           1  1027  Ethereum    ETH  ethereum              6125
# 2           2   825    Tether   USDT    tether             40506
# 3           3  1839       BNB    BNB       bnb              1121
# 4           4  3408  USD Coin   USDC  usd-coin              6437
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2018-10-08T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...   21000000.0
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...          NaN
# 2  ['payments', 'stablecoin', 'asset-backed-stabl...          NaN
# 3  ['marketplace', 'centralized-exchange', 'payme...  200000000.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2015 entries, 0 to 2014
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          2015 non-null   int64
#  1   id                                  2015 non-null   int64
#  2   name                                2015 non-null   object
#  3   symbol                              2015 non-null   object
#  4   slug                                2015 non-null   object
#  5   num_market_pairs                    2015 non-null   int64
#  6   date_added                          2015 non-null   object
#  7   tags                                2015 non-null   object
#  8   max_supply                          1305 non-null   float64
#  9   circulating_supply                  2015 non-null   float64
#  10  total_supply                        2015 non-null   float64
# ...

# %%
pd.set_option('display.float_format' , lambda x : '%.5f' % x)

# %%
df3.head()
# Out:
#    Unnamed: 0    id      name symbol      slug  num_market_pairs  \
# 0           0     1   Bitcoin    BTC   bitcoin              9764
# 1           1  1027  Ethereum    ETH  ethereum              6125
# 2           2   825    Tether   USDT    tether             40506
# 3           3  1839       BNB    BNB       bnb              1121
# 4           4  3408  USD Coin   USDC  usd-coin              6437
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2018-10-08T00:00:00.000Z
#
#                                                 tags      max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...  21000000.00000
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...             NaN
# 2  ['payments', 'stablecoin', 'asset-backed-stabl...             NaN
# 3  ['marketplace', 'centralized-exchange', 'payme... 200000000.00000
# ...
